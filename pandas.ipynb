# %%
import pandas as pd
import numpy as np

working_data = pd.read_csv("employee_survey.csv")
#workig_data.head()
#working_data.tail()
working_data.info()
#working_data.describe()
df = pd.DataFrame(working_data)
df
#series = pd.Series([1, 2, 3, 4, 5])
#series
#get all data sample under gender
#working_data.loc[1,"Gender"]
#working_data.size
#working_data.shape
#working_data.ndim
working_data.empty
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3025 entries, 0 to 3024
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmpID                  3025 non-null   int64
#  1   Gender                 3025 non-null   str
#  2   Age                    3025 non-null   int64
#  3   MaritalStatus          3025 non-null   str
#  4   JobLevel               3025 non-null   str
#  5   Experience             3025 non-null   int64
#  6   Dept                   3025 non-null   str
#  7   EmpType                3025 non-null   str
#  8   WLB                    3025 non-null   int64
#  9   WorkEnv                3025 non-null   int64
#  10  PhysicalActivityHours  3025 non-null   float64
#  11  Workload               3025 non-null   int64
#  12  Stress                 3025 non-null   int64
#  13  SleepHours             3025 non-null   float64
#  14  CommuteMode            3025 non-null   str
# ...

# %%
working_data.describe
# Out:
# <bound method NDFrame.describe of       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...

# %%
working_data.size
# Out:
# 69575

# %%
working_data.head()
# Out:
#    EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0      6    Male   32       Married             Mid           7         IT
# 1     11  Female   34       Married             Mid          12    Finance
# 2     33  Female   23        Single  Intern/Fresher           1  Marketing
# 3     20  Female   29       Married          Junior           6         IT
# 4     28   Other   23        Single          Junior           1      Sales
#
#      EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 0  Full-Time    1        1  ...         7.6               Car
# 1  Full-Time    1        1  ...         7.9               Car
# 2  Full-Time    2        4  ...         6.5         Motorbike
# 3   Contract    2        2  ...         7.5  Public Transport
# 4  Part-Time    3        1  ...         4.9               Car
#
#    CommuteDistance  NumCompanies TeamSize  NumReports  EduLevel  haveOT  \
# ...

# %%
working_data.info
# Out:
# <bound method DataFrame.info of       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...

# %%
sample_size = working_data.sample(10)
sample_size
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience        Dept  \
# 831     631  Female   27        Single   Junior           5  Operations
# 2906   1539    Male   47       Married     Lead           8       Legal
# 1725   2796    Male   31       Married      Mid           5          IT
# 1379    580   Other   26        Single   Junior           4  Operations
# 1023   2659  Female   48       Married      Mid          10  Operations
# 196       2  Female   32        Single   Senior          10          HR
# 2609   1187  Female   32        Single   Senior           8  Operations
# 2833   2120   Other   43        Single   Senior           4          IT
# 390    1487  Female   35       Married      Mid          13          IT
# 2951   2598    Male   44       Married     Lead          22       Sales
#
#         EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 831   Part-Time    2        5  ...         6.8  Public Transport
# ...

# %%
#Loop trough the sample_size, print label and value
for label, value in sample_size.items():
    print(label)
    print(value)
# Out:
# EmpID
# 831      631
# 2906    1539
# 1725    2796
# 1379     580
# 1023    2659
# 196        2
# 2609    1187
# 2833    2120
# 390     1487
# 2951    2598
# Name: EmpID, dtype: int64
# Gender
# 831     Female
# 2906      Male
# 1725      Male
# 1379     Other
# 1023    Female
# 196     Female
# 2609    Female
# 2833     Other
# 390     Female
# 2951      Male
# Name: Gender, dtype: str
# Age
# 831     27
# 2906    47
# 1725    31
# 1379    26
# 1023    48
# 196     32
# 2609    32
# 2833    43
# 390     35
# 2951    44
# Name: Age, dtype: int64
# MaritalStatus
# 831      Single
# 2906    Married
# 1725    Married
# 1379     Single
# 1023    Married
# 196      Single
# 2609     Single
# 2833     Single
# 390     Married
# 2951    Married
# Name: MaritalStatus, dtype: str
# JobLevel
# 831     Junior
# 2906      Lead
# 1725       Mid
# 1379    Junior
# 1023       Mid
# 196     Senior
# 2609    Senior
# 2833    Senior
# 390        Mid
# 2951      Lead
# Name: JobLevel, dtype: str
# ...

# %%
sample_size[sample_size['Age'] > 25]
# Out:
#       EmpID  Gender  Age MaritalStatus JobLevel  Experience        Dept  \
# 831     631  Female   27        Single   Junior           5  Operations
# 2906   1539    Male   47       Married     Lead           8       Legal
# 1725   2796    Male   31       Married      Mid           5          IT
# 1379    580   Other   26        Single   Junior           4  Operations
# 1023   2659  Female   48       Married      Mid          10  Operations
# 196       2  Female   32        Single   Senior          10          HR
# 2609   1187  Female   32        Single   Senior           8  Operations
# 2833   2120   Other   43        Single   Senior           4          IT
# 390    1487  Female   35       Married      Mid          13          IT
# 2951   2598    Male   44       Married     Lead          22       Sales
#
#         EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 831   Part-Time    2        5  ...         6.8  Public Transport
# ...

# %%
sample_size[sample_size['Age'] < 25]
# Out:
# Empty DataFrame
# Columns: [EmpID, Gender, Age, MaritalStatus, JobLevel, Experience, Dept, EmpType, WLB, WorkEnv, PhysicalActivityHours, Workload, Stress, SleepHours, CommuteMode, CommuteDistance, NumCompanies, TeamSize, NumReports, EduLevel, haveOT, TrainingHoursPerYear, JobSatisfaction]
# Index: []
#
# [0 rows x 23 columns]

# %%
sample_size.info
# Out:
# <bound method DataFrame.info of       EmpID  Gender  Age MaritalStatus JobLevel  Experience        Dept  \
# 831     631  Female   27        Single   Junior           5  Operations
# 2906   1539    Male   47       Married     Lead           8       Legal
# 1725   2796    Male   31       Married      Mid           5          IT
# 1379    580   Other   26        Single   Junior           4  Operations
# 1023   2659  Female   48       Married      Mid          10  Operations
# 196       2  Female   32        Single   Senior          10          HR
# 2609   1187  Female   32        Single   Senior           8  Operations
# 2833   2120   Other   43        Single   Senior           4          IT
# 390    1487  Female   35       Married      Mid          13          IT
# 2951   2598    Male   44       Married     Lead          22       Sales
#
#         EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 831   Part-Time    2        5  ...         6.8  Public Transport
# ...

# %%
d = {"b": 1, "a": 0, "c": 2}

pd.Series(d)

bet = {"shoe": 200, "book": 300, "snacks": 400, "rent": 500, "vacation": 600, "data_sub.": 1000}
#pd.Series(bet)
for key, value in bet.items():
    total = sum(bet.values())
    print(f"Total Sum = {total}")
    break
    if value <= 100:
         print(value)
    elif value > 500:
         print(value)
    elif value == max:
         print(value)
# Out:
# Total Sum = 3000

# %%
bet = {"shoe": 200, "book": 300, "snacks": 400, "rent": 500, "vacation": 600, "data_sub.": 1000}
pd.Series(bet)
# Out:
# shoe          200
# book          300
# snacks        400
# rent          500
# vacation      600
# data_sub.    1000
# dtype: int64

# %%
working_data = pd.read_csv("employee_survey.csv")
working_data.info()


for key, value in working_data.items():
    print(f"{key} is Key")
    print(f"{value} is Value")

    add = sum(value)
    print(add, "Total sum of sample")

    f = len(value)
    print(f, "Number of occurrences")

    mean = sum(value) / len(value)
    print(mean)
    #OR
    _x = add / f
    print(_x, "is our mean value")

    #big = max(value)
    #print(big, "is our max value")

    #small = min(value)
    #print(small, "is our min value")

    #R = big - small
    #print(R, "is our range value")

    std = value.std()
    print(std, "is our standard deviation value")
    break
working_data.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3025 entries, 0 to 3024
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmpID                  3025 non-null   int64
#  1   Gender                 3025 non-null   str
#  2   Age                    3025 non-null   int64
#  3   MaritalStatus          3025 non-null   str
#  4   JobLevel               3025 non-null   str
#  5   Experience             3025 non-null   int64
#  6   Dept                   3025 non-null   str
#  7   EmpType                3025 non-null   str
#  8   WLB                    3025 non-null   int64
#  9   WorkEnv                3025 non-null   int64
#  10  PhysicalActivityHours  3025 non-null   float64
#  11  Workload               3025 non-null   int64
#  12  Stress                 3025 non-null   int64
#  13  SleepHours             3025 non-null   float64
#  14  CommuteMode            3025 non-null   str
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Bennie", "Paul", "Peter", "John"],
    "Age": [23,33,54,19],
    "Sex": ["Female", "Male", "Male", "Male"],
})
df
df["Age"]

for value in df.Age:
    print(value)
    if value > 50:
        print(f"Worker should be considered to retire at {value}")
        break
df["Name"]
df
for name in df.Name:
    if "Paul" and "John" in name:
        print(f"{name} has no duplicate")
        break


df.describe()
# Out:
# 23
# 33
# 54
# Worker should be considered to retire at 54
# John has no duplicate
#              Age
# count   4.000000
# mean   32.250000
# std    15.649814
# min    19.000000
# 25%    22.000000
# 50%    28.000000
# 75%    38.250000
# max    54.000000

# %%
employee = pd.read_csv("employee_survey.csv")
employee
# Out:
#       EmpID  Gender  Age MaritalStatus        JobLevel  Experience       Dept  \
# 0         6    Male   32       Married             Mid           7         IT
# 1        11  Female   34       Married             Mid          12    Finance
# 2        33  Female   23        Single  Intern/Fresher           1  Marketing
# 3        20  Female   29       Married          Junior           6         IT
# 4        28   Other   23        Single          Junior           1      Sales
# ...     ...     ...  ...           ...             ...         ...        ...
# 3020   2070    Male   47       Married            Lead          16  Marketing
# 3021   2072  Female   47       Married            Lead           8         IT
# 3022   2145    Male   41       Married            Lead          17         IT
# 3023   2168  Female   54       Married            Lead          16         IT
# 3024   2183  Female   44       Married            Lead          22  Marketing
#
# ...

# %%
employee.head(10)
# Out:
#    EmpID  Gender  Age MaritalStatus        JobLevel  Experience        Dept  \
# 0      6    Male   32       Married             Mid           7          IT
# 1     11  Female   34       Married             Mid          12     Finance
# 2     33  Female   23        Single  Intern/Fresher           1   Marketing
# 3     20  Female   29       Married          Junior           6          IT
# 4     28   Other   23        Single          Junior           1       Sales
# 5     45  Female   33       Married             Mid          10  Operations
# 6     21  Female   26        Single          Junior           4       Sales
# 7     44    Male   24        Single          Junior           2          IT
# 8      7  Female   29       Married          Junior           7   Marketing
# 9     15  Female   24        Single             Mid           2   Marketing
#
#      EmpType  WLB  WorkEnv  ...  SleepHours       CommuteMode  \
# 0  Full-Time    1        1  ...         7.6               Car
# ...

# %%
employee["Gender"]
# Out:
# 0         Male
# 1       Female
# 2       Female
# 3       Female
# 4        Other
#          ...
# 3020      Male
# 3021    Female
# 3022      Male
# 3023    Female
# 3024    Female
# Name: Gender, Length: 3025, dtype: str

# %%
employee["Age"]
# Out:
# 0       32
# 1       34
# 2       23
# 3       29
# 4       23
#         ..
# 3020    47
# 3021    47
# 3022    41
# 3023    54
# 3024    44
# Name: Age, Length: 3025, dtype: int64

# %%
employee["Age"].max()
for value in employee.Age :
    print(value)
    if value >= 33:
        print(value)
        break

for num in employee.Experience:
    if num > 15:
        print(f"{num} is considered best job total working experience")
# Out:
# 32
# 34
# 34
# 23 is considered best job total working experience
# 18 is considered best job total working experience
# 26 is considered best job total working experience
# 25 is considered best job total working experience
# 17 is considered best job total working experience
# 16 is considered best job total working experience
# 25 is considered best job total working experience
# 23 is considered best job total working experience
# 21 is considered best job total working experience
# 21 is considered best job total working experience
# 16 is considered best job total working experience
# 16 is considered best job total working experience
# 19 is considered best job total working experience
# 17 is considered best job total working experience
# 17 is considered best job total working experience
# 24 is considered best job total working experience
# 16 is considered best job total working experience
# 20 is considered best job total working experience
# ...
